# %%
#
import pandas as pd
df = pd.read_csv ('commodities1.csv',index_col=0)
#printing the head() elements in the csv data
print("head()-function")
print(df.head())
#to print the particular no of elements from the head
print("head(n)-function")
print(df.head(3))
#printing the data from the bottom of the csv data
print("tail()-function")
print(df.tail())
#printing the particular no of elements from bottom from the csv file
print("tail(n)-function")
print(df.tail(3))
#printing the particular element any where in the csv data
print("take()-function")
print(df.take([1, 3, 5]))
# Out:
# head()-function
#         Item  Quantity(kg)  Cost
# s.no
# 1       Rice             1    50
# 2     Tomato             1    35
# 3       Daal             1    80
# 4       salt             1    20
# 5        Oil             1   120
# head(n)-function
#         Item  Quantity(kg)  Cost
# s.no
# 1       Rice             1    50
# 2     Tomato             1    35
# 3       Daal             1    80
# tail()-function
#            Item  Quantity(kg)  Cost
# s.no
# 6     Groundnut             1   150
# 7        Chilli             1    75
# 8       brinjal             1    40
# 9       cabbage             1    40
# 10        sugar             1    50
# tail(n)-function
#          Item  Quantity(kg)  Cost
# s.no
# 8     brinjal             1    40
# 9     cabbage             1    40
# 10      sugar             1    50
# take()-function
#            Item  Quantity(kg)  Cost
# s.no
# 2        Tomato             1    35
# 4          salt             1    20
# ...

# %%
#.rolling() Function
print("\nrolling function")
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('6/10/2020', periods=10),
   columns = ['A', 'B', 'C', 'D'])
print (df.rolling(window=3).mean())
#.expanding() Function
print("\nexpanding function")
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])
print(df.expanding(min_periods=3).mean())
#.ewm() Function
print("\newm function")
import pandas as pd
import numpy as np
 
df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])
print (df.ewm(com=0.5).mean())
# Out:
# rolling function
#                    A         B         C         D
# 2020-06-10       NaN       NaN       NaN       NaN
# 2020-06-11       NaN       NaN       NaN       NaN
# 2020-06-12 -0.464446  0.077735  0.331897 -0.106942
# 2020-06-13  0.388712  0.045826  0.065876 -0.477666
# 2020-06-14  0.451360 -0.145489 -0.356444  0.037478
# 2020-06-15  0.081277 -0.050352  0.003039 -0.371138
# 2020-06-16  0.413340 -0.266961 -0.137907 -0.726444
# 2020-06-17  0.075967 -0.266172  0.095386 -0.893152
# 2020-06-18 -0.202232 -0.162425 -0.380276 -0.407995
# 2020-06-19 -0.958987 -0.240392 -0.419614  0.209772
#
# expanding function
#                    A         B         C         D
# 2000-01-01       NaN       NaN       NaN       NaN
# 2000-01-02       NaN       NaN       NaN       NaN
# 2000-01-03  1.112687  0.038164 -0.253949  0.010372
# 2000-01-04  1.101752 -0.040212  0.131910  0.184803
# 2000-01-05  0.506106  0.096607  0.217813  0.380481
# 2000-01-06  0.429982  0.193653  0.549398  0.188749
# ...
