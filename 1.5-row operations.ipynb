# %%
#retireving data from csv file
import pandas as pd
df = pd.read_csv ('commodities2.csv',index_col=0)
print("\n------------ BEFORE ----------------\n")
print(df)
#Adding row at the end
df.loc[len(df)] = ['pickle',5, 550] 
print("\n------------ AFTER ----------------\n")
print(df)
print("\n")
#Add row with specific index name
print("Adding row with specific index name to the data")
print("\n------------ BEFORE ----------------\n")
print(df)
df.loc['15'] = ['chicken', 2, 360]
print("\n------------ AFTER ----------------\n")
print(df)
print("here the desired index position is 15\n")
# Out:
# ------------ BEFORE ----------------
#
#            Item  Quantity(kg)  Cost
# s.no
# 1          Rice          10.5    50
# 2        Tomato           2.5    35
# 3          Daal           3.5    80
# 4          salt           2.0    20
# 5           Oil           5.0   120
# 6     Groundnut           1.0   150
# 7        Chilli           1.5    75
# 8       brinjal           3.0    40
# 9       cabbage           2.5    40
# 10        sugar           6.5    50
#
# ------------ AFTER ----------------
#
#            Item  Quantity(kg)  Cost
# s.no
# 1          Rice          10.5    50
# 2        Tomato           2.5    35
# 3          Daal           3.5    80
# 4          salt           2.0    20
# 5           Oil           5.0   120
# 6     Groundnut           1.0   150
# 7        Chilli           1.5    75
# 8       brinjal           3.0    40
# 9       cabbage           2.5    40
# 10       pickle           5.0   550
#
#
# Adding row with specific index name to the data
#
# ------------ BEFORE ----------------
#
#            Item  Quantity(kg)  Cost
# s.no
# 1          Rice          10.5    50
# 2        Tomato           2.5    35
# 3          Daal           3.5    80
# 4          salt           2.0    20
# 5           Oil           5.0   120
# 6     Groundnut           1.0   150
# 7        Chilli           1.5    75
# 8       brinjal           3.0    40
# 9       cabbage           2.5    40
# 10       pickle           5.0   550
#
# ------------ AFTER ----------------
#
#            Item  Quantity(kg)  Cost
# s.no
# 1          Rice          10.5    50
# 2        Tomato           2.5    35
# 3          Daal           3.5    80
# 4          salt           2.0    20
# 5           Oil           5.0   120
# 6     Groundnut           1.0   150
# 7        Chilli           1.5    75
# 8       brinjal           3.0    40
# 9       cabbage           2.5    40
# 10       pickle           5.0   550
# 15      chicken           2.0   360
# here the desired index position is 15
